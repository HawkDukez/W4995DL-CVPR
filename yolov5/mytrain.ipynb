# %%
# !python train.py --img 640 --batch 40 --epochs 5000 --data CVPR_dehaze.yaml --weights ./runs/train/exp2/weights/best.pt
# Out:
# train: weights=./runs/train/exp2/weights/best.pt, cfg=, data=CVPR_dehaze.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=5000, batch_size=40, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 12 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-276-ga936f5f torch 1.10.0 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
